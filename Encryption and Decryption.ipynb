# %%
def caesar_cipher(text, shift):
    result = ''
    for char in text:
        if char.isalpha():
            if char.isupper():
                result += chr((ord(char) + shift - 65) % 26 + 65)
            else:
                result += chr((ord(char) + shift - 97) % 26 + 97)
        else:
            result += char
    return result

def substitution_cipher(text, key):
    result = ''
    for char in text:
        if char.isalpha():
            if char.isupper():
                result += key[ord(char) - 65].upper()
            else:
                result += key[ord(char) - 97]
        else:
            result += char
    return result


def dec_caesar_cipher(text, shift):
    result = ''
    for char in text:
        if char.isalpha():
            if char.isupper():
                result += chr((ord(char) - shift - 65) % 26 + 65)
            else:
                result += chr((ord(char) - shift - 97) % 26 + 97)
        else:
            result += char
    return result

def dec_substitution_cipher(text, key):
    result = ''
    for char in text:
        if char.isalpha():
            if char.isupper():
              index = key.find(char)
              result += chr(index + 65).upper()
            else:
              index = key.find(char)
              result += chr(index + 97)

        else:
          result += char
    return result.lower()

def combine_cipher(text, shift, key):
    text = caesar_cipher(text, shift)
    text = substitution_cipher(text, key)
    return text

def decrypt_combine_cipher(text, shift, key):
    text = dec_substitution_cipher(text, key)
    text = dec_caesar_cipher(text, shift)
    return text

text = input("Text: ")
shift = int(input("Shift: "))
key = input("Key: ")

print("Text :",text)
print("Shift :",shift)
print("Key :",key)

encrypted_text = combine_cipher(text, shift, key)
print("\nHasil Encrypt: ",encrypted_text)

decrypted_text = decrypt_combine_cipher(encrypted_text, shift, key)
print("Hasil Decrypt: ",decrypted_text)
# Out:
# Text : kol
# Text : 6
# Text : qwertyuiopasdfghjklzxcvbnm
#
# Hasil Encrypt:  jxk
# Hasil Decrypt:  kol
